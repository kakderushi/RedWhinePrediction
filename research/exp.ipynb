# %%
import os

# %%
import pandas as pd

# %%
wines=pd.read_csv("winequality-red.csv")

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wines.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1591            6.2             0.600         0.08             2.0      0.090
# 1592            5.9             0.550         0.10             2.2      0.062
# 1593            6.3             0.510         0.13             2.3      0.076
# 1594            5.9             0.645         0.12             2.0      0.075
# 1595            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1591                 32.0                  44.0  0.99490  3.45       0.58
# 1592                 39.0                  51.0  0.99512  3.52       0.76
# 1593                 29.0                  40.0  0.99574  3.42       0.75
# 1594                 32.0                  44.0  0.99547  3.57       0.71
# 1595                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1591     10.5        5
# 1592     11.2        6
# 1593     11.0        6
# 1594     10.2        5
# 1595     11.0        6
#
# [1596 rows x 12 columns]>

# %%
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1596.000000       1596.000000  1596.000000     1596.000000
# mean        8.314160          0.527954     0.270276        2.535558
# std         1.732203          0.179176     0.193894        1.405515
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.600000          1.580000     0.790000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1596.000000          1596.000000           1596.000000  1596.000000
# mean      0.087120            15.858396             46.382206     0.996744
# std       0.045251            10.460554             32.839138     0.001888
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996745
# 75%       0.090000            21.000000             62.000000     0.997833
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1596.000000  1596.000000  1596.000000  1596.000000
# mean      3.311917     0.656385    10.421147     5.637218
# std       0.153346     0.163057     1.060371     0.807080
# min       2.860000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     1.980000    14.000000     8.000000

# %%
import matplotlib.pyplot as plt
wines.hist(bins=50,figsize=(20,15),color='orange')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
x=wines.drop(['quality'],axis=1)

# %%
y=wines['quality']

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1591            6.2             0.600         0.08             2.0      0.090
# 1592            5.9             0.550         0.10             2.2      0.062
# 1593            6.3             0.510         0.13             2.3      0.076
# 1594            5.9             0.645         0.12             2.0      0.075
# 1595            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1591                 32.0                  44.0  0.99490  3.45       0.58
# 1592                 39.0                  51.0  0.99512  3.52       0.76
# 1593                 29.0                  40.0  0.99574  3.42       0.75
# 1594                 32.0                  44.0  0.99547  3.57       0.71
# 1595                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1591     10.5
# 1592     11.2
# 1593     11.0
# 1594     10.2
# 1595     11.0
#
# [1596 rows x 11 columns]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1591    5
# 1592    6
# 1593    6
# 1594    5
# 1595    6
# Name: quality, Length: 1596, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import ElasticNet

# %%
lr = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
lr.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=0.1, random_state=42)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)

    return rmse, mae, r2

# %%
predicted_value = lr.predict(x_test)

# %%
predicted_value
# Out:
# array([5.77910777, 5.93861228, 5.3762938 , 5.83405313, 5.74408048,
#        5.54338231, 5.44487678, 6.23866973, 5.96897268, 5.95786262,
#        6.28191901, 6.0444623 , 5.3907293 , 5.25297761, 5.85252011,
#        5.49915013, 5.36337336, 5.17100083, 5.24567231, 5.44501728,
#        5.656592  , 5.34591515, 6.11901702, 5.31274619, 5.48224473,
#        5.45827371, 5.62472935, 5.70714946, 5.32865795, 5.98221986,
#        6.01991605, 5.70305353, 5.88093205, 5.53089016, 5.29854035,
#        5.44459389, 6.71871467, 5.6012882 , 5.44101975, 5.36346566,
#        5.72026183, 5.24120078, 5.58097493, 5.24510429, 5.77352499,
#        5.5950719 , 5.4031078 , 5.13713626, 5.18740659, 6.65331656,
#        5.38759391, 5.76181326, 5.08487831, 5.33327556, 5.61834205,
#        5.39360388, 6.34559591, 5.27838909, 5.27033836, 5.91007743,
#        5.79523013, 5.24552314, 6.16495599, 5.86900702, 5.61556201,
#        5.46076158, 5.3907293 , 5.79206317, 6.36343891, 5.45429437,
#        5.56673643, 5.94465832, 6.25371266, 5.97988863, 5.80372848,
#        5.20976906, 5.32459087, 5.43248463, 5.99850773, 5.85214879,
#        5.1446366 , 5.75478464, 5.75865914, 5.82561182, 6.28174377,
#        5.42288267, 5.46443161, 5.76181326, 5.65992863, 5.14681746,
#        5.13702712, 6.13934028, 4.96093463, 6.00414256, 6.36043105,
#        5.34303266, 5.84075947, 6.02469393, 5.50987858, 5.62814753,
#        5.72172445, 6.30084054, 5.5391015 , 5.94967824, 5.53438802,
#        5.8179889 , 6.65759358, 5.46443161, 5.85669406, 5.23908794,
#        5.32343392, 5.31231705, 5.43730344, 5.38353601, 5.19077936,
#        5.27314463, 5.75534968, 5.24208577, 5.72550477, 5.43898106,
#        5.30026956, 5.38164321, 5.79489528, 5.93288815, 5.67747713,
#        6.01177542, 5.3996478 , 5.38114161, 5.20155335, 5.48379733,
#        5.62815062, 5.18681081, 5.1807908 , 5.36909291, 5.3615978 ,
#        5.88059026, 6.00210882, 5.97518444, 5.47175916, 5.69974086,
#        5.72172445, 6.61825305, 5.25301289, 5.80777478, 5.14767849,
#        5.27033836, 5.42015038, 5.45864612, 6.11353684, 5.12385106,
#        6.18158694, 6.06377786, 5.43040385, 5.62436625, 5.45681762,
#        5.3615978 , 5.88310678, 5.622346  , 6.04786336, 5.73037757,
#        5.47091019, 6.20121995, 5.23232183, 5.29374546, 5.39503523,
#        5.32117324, 5.8179889 , 6.31857477, 5.60821395, 5.3996478 ,
#        6.12597916, 6.25915762, 5.6241861 , 5.84515753, 5.55171702,
#        5.28835567, 5.68957416, 6.39821871, 5.27418115, 5.34000392,
#        5.34111486, 5.71986391, 6.22208633, 5.23652982, 5.18239227,
#        5.59401563, 5.28690837, 5.33426341, 5.20257644, 5.51080833,
#        5.70951727, 6.08538991, 5.43795499, 5.620807  , 5.96107764,
#        6.19061421, 5.12254612, 5.28380292, 5.34661172, 6.05881007,
#        5.71498086, 5.45353282, 5.67086813, 6.23757631, 5.97882139,
#        5.70865383, 5.14445252, 5.90587757, 5.95786262, 5.6353278 ,
#        6.21492291, 6.14047322, 6.00466234, 6.07227883, 5.3428709 ,
#        5.44871609, 5.25732913, 5.65603444, 6.14631298, 5.12526344,
#        5.7698444 , 5.21705689, 6.28841806, 5.65151205, 5.92863113,
#        5.41220741, 5.39148593, 5.65947644, 5.66482729, 5.83933311,
#        5.84850931, 6.19747674, 5.28387671, 5.31585687, 5.26941481,
#        5.53786282, 5.2502766 , 5.75478464, 5.40800914, 5.32117324,
#        5.51097708, 5.63758112, 5.65265643, 5.59091938, 5.32720128,
#        5.93045036, 5.21089259, 5.86440787, 5.73547695, 5.31955725,
#        5.28106248, 5.9398859 , 6.13509986, 5.25301289, 6.44028918,
#        5.63405372, 5.73570198, 5.21764031, 5.6102985 , 5.96546961,
#        6.00244583, 5.25432647, 6.21061514, 5.68955133, 5.14759488,
#        5.40111985, 5.85638426, 5.11756647, 6.19528789, 6.76843905,
#        5.50539766, 5.73787676, 6.15460826, 5.3223764 , 5.75497787,
#        6.1794404 , 5.1194995 , 5.67047011, 5.78657604, 5.23499918,
#        5.76047625, 5.3183331 , 6.13819903, 5.17303648, 5.4503394 ,
#        5.27418115, 5.31567971, 6.11375043, 6.01065813, 5.54826913,
#        5.40002516, 5.35296865, 5.35045099, 6.11308579, 5.09864868,
#        5.25433604, 6.32542282, 5.72714923, 5.4756048 , 5.12697409,
#        5.31955725, 5.30233611, 5.44941968, 5.73296861, 6.5023465 ,
#        5.96404731, 5.91667407, 5.51028148, 5.44951403, 6.36517007,
#        5.48422339, 6.06931656, 6.3312226 , 5.60813965, 6.3458833 ,
#        5.50283749, 6.25511945, 5.31106498, 5.88794119, 5.87404329])

# %%
(rmse, mae, r2) = eval_metrics(y_test, predicted_value)

# %%
print("rmse = ", rmse)
print("mae = ", mae)
print("r2 = ", r2)
# Out:
# rmse =  0.7297001676287264
# mae =  0.583574438555506
# r2 =  0.19853973825360682
